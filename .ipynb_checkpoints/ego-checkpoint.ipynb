# %%
from functions.functions import *
from lamcts.bayesian_opt import optimize

# %%
f = myFunc()
# Out:
# Creation of the directory myFunc failed

# %%
f([0.5])
# Out:
# array([[-0.00415178]])

# %%
n_runs = 10
n_eval = 100
n_init_eval = 10

# %%
opt_x = optimize(n_eval, n_init_eval, f)
# Out:
# 11: x [0.63424263 0.81401705 0.38009853 0.20538094 0.45958769 0.56492384
#  0.16326733 0.75301786 0.69444225 0.91305004 0.55500391 0.2650455
#  0.26935175 0.37973434 0.55630841 0.47185806 0.92160263 0.52938463] y -0.011254330246342183  Best-so-far -0.005640003828592058
# 12: x [0.25530563 0.51404687 0.98321788 0.55880299 0.74175943 0.79849406
#  0.87395816 0.49964961 0.47274111 0.94995055 0.4623537  0.15078411
#  0.18937622 0.94160544 0.24924569 0.89758675 0.9882478  0.87905871] y -0.008961651491924473  Best-so-far -0.005640003828592058
# 13: x [0.61413483 0.82064586 0.7151816  0.49435552 0.33286065 0.83754533
#  0.82731513 0.30309066 0.89993527 0.86365881 0.87204385 0.39959444
#  0.07266584 0.83187946 0.06945427 0.59538038 0.92705303 0.98425528] y -0.012127034144450757  Best-so-far -0.005640003828592058
# 14: x [0.953209   0.55635709 0.48339059 0.86887715 0.916919   0.81204046
#  0.37420287 0.28615073 0.60389347 0.04298456 0.92920402 0.07020937
# ...
